# %% [markdown]
# ##### In the while loop, the video frames are continuously read from the camera using the cap.read() method, and each frame is displayed in a window named "vid" using the cv2.imshow() method. The loop runs until the user presses the 'q' key, at which point the loop is exited and the window is closed using the cv2.destroyAllWindows() method.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The three Functions

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Inverted Axis

# %% [markdown]
# ![image.png](attachment:image.png)
